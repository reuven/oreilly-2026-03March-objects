# %% [markdown]
# # Agenda, day 2
#
# 1. Recap + Q&A
# 2. Magic methods
# 3. Class attributes
# 4. Finding attributes with ICPO (instance-class-parent-object rule)
# 5. Inheritance -- and how ICPO affects it
# 6. Three models for understanding and usi
